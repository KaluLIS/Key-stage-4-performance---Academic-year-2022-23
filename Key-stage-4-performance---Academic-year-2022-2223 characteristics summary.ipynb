# %%
# My Project
# Key-stage-4-performance---Academic-year-2022-23/2223_characteristics_summary_data_revised.csv

# %%
# import Python's library warning module
import warnings
warnings.filterwarnings("ignore")

# Import necessary libraries
import numpy as np
import pandas as pd
import io
import requests

# Load the CSV file from GitHub
df_url = 'https://raw.githubusercontent.com/KaluLIS/Key-stage-4-performance---Academic-year-2022-23/refs/heads/main/2223_characteristics_summary_data_revised.csv?token=GHSAT0AAAAAACZVDMQUAKCJRFCSFZJ4VFIKZZBHI3A'
url_content = requests.get(df_url, verify = False).content
nc = pd.read_csv(io.StringIO(url_content.decode('utf-8')))

# %%
#Data Variables

# %%
nc.describe()
# Out:
#          time_period    t_schools       t_pupils        t_att8    avg_att8  \
# count     264.000000   264.000000     264.000000  2.640000e+02  264.000000
# mean   202020.234848  2395.393939   97996.125000  4.758795e+06   42.393561
# std       142.833513  1182.877160  167382.721258  8.398242e+06   13.332299
# min    201819.000000    94.000000     126.000000  9.207500e+02    1.700000
# 25%    201920.000000  1451.750000    4006.250000  1.610239e+05   35.375000
# 50%    202021.000000  2458.000000   12071.500000  5.315065e+05   46.300000
# 75%    202122.000000  3406.500000   73189.500000  3.453905e+06   50.825000
# max    202223.000000  4047.000000  606915.000000  2.931931e+07   69.200000
#
#          t_entbasics  pt_entbasics  t_l2basics_95  pt_l2basics_95  \
# count     264.000000    264.000000     264.000000      264.000000
# mean    94799.541667     89.929545   47095.056818       39.181439
# std    163488.487037     18.069369   85379.583506       18.949739
# ...

# %%
# info() method for more deets
print("\nDataFrame Info:")
nc.info()
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   time_period            264 non-null    int64
#  1   time_identifier        264 non-null    object
#  2   geographic_level       264 non-null    object
#  3   country_code           264 non-null    object
#  4   country_name           264 non-null    object
#  5   version                264 non-null    object
#  6   establishment_type     264 non-null    object
#  7   characteristics_group  264 non-null    object
#  8   characteristic         264 non-null    object
#  9   t_schools              264 non-null    int64
#  10  t_pupils               264 non-null    int64
#  11  t_att8                 264 non-null    float64
#  12  avg_att8               264 non-null    float64
#  13  t_entbasics            264 non-null    int64
# ...

# %%
print("\nDataFrame Summary Statistics:")
print(nc.describe())
# Out:
# DataFrame Summary Statistics:
#          time_period    t_schools       t_pupils        t_att8    avg_att8  \
# count     264.000000   264.000000     264.000000  2.640000e+02  264.000000
# mean   202020.234848  2395.393939   97996.125000  4.758795e+06   42.393561
# std       142.833513  1182.877160  167382.721258  8.398242e+06   13.332299
# min    201819.000000    94.000000     126.000000  9.207500e+02    1.700000
# 25%    201920.000000  1451.750000    4006.250000  1.610239e+05   35.375000
# 50%    202021.000000  2458.000000   12071.500000  5.315065e+05   46.300000
# 75%    202122.000000  3406.500000   73189.500000  3.453905e+06   50.825000
# max    202223.000000  4047.000000  606915.000000  2.931931e+07   69.200000
#
#          t_entbasics  pt_entbasics  t_l2basics_95  pt_l2basics_95  \
# count     264.000000    264.000000     264.000000      264.000000
# mean    94799.541667     89.929545   47095.056818       39.181439
# ...

# %%
nc.iloc
nc.groupby('region_name' 'school_type' 'attainment_level').std()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 nc.iloc
# ----> 2 nc.groupby('region_name' 'school_type' 'attainment_level').std()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
print(nc.columns.tolist())

# %%
nc.iloc
nc.groupby('t_pupils').std()

# %%
# time_period: The specific time period (usually a school year) that the data covers.
# time_identifier: An identifier associated with the time period, often used for filtering or sorting (e.g., "2022-2023").
# geographic_level: Indicates the geographic granularity of the data, such as "national," "regional," or "school-level."
# country_code: A standardised code representing the country (e.g., "UK" for the United Kingdom).
# country_name: The full name of the country (e.g., "United Kingdom").
# version: The dataset version, which may indicate updates or revisions.
# establishment_type: Type of educational institution (e.g., "primary school," "secondary school").
# characteristics_group: A broader category grouping individual characteristics (e.g., "disadvantaged," "non-disadvantaged").
# characteristic: A specific demographic or educational characteristic, such as "male" or "female."
# t_schools: Total number of schools within the specified grouping.
# t_pupils: Total number of pupils within the specified grouping.
# t_att8: Total Attainment 8 score across all pupils in the grouping.
# avg_att8: Average Attainment 8 score per pupil in the grouping.
# t_entbasics: Total number of pupils who entered basic education requirements.
# pt_entbasics: Percentage of pupils who entered basic education requirements.
# t_l2basics_95: Total pupils who achieved Level 2 basics at a grade 9-5.
# pt_l2basics_95: Percentage of pupils who achieved Level 2 basics at a grade 9-5.
# t_l2basics_94: Total pupils who achieved Level 2 basics at a grade 9-4.
# pt_l2basics_94: Percentage of pupils who achieved Level 2 basics at a grade 9-4.
# t_ebacc_e_ptq_ee: Total pupils who entered the English Baccalaureate (EBacc) with a qualifying English entry.
# pt_ebacc_e_ptq_ee: Percentage of pupils who entered the English Baccalaureate with a qualifying English entry.
# t_ebacc_95: Total number of pupils who achieved EBacc at a grade 9-5.
# pt_ebacc_95: Percentage of pupils who achieved EBacc at a grade 9-5.
# t_ebacc_94: Total number of pupils who achieved EBacc at a grade 9-4.
# pt_ebacc_94: Percentage of pupils who achieved EBacc at a grade 9-4.
# t_ebaccaps: Total EBacc APS (average point score) for the group.
# avg_ebaccaps: Average EBacc APS (average point score) per pupil.
# t_inp8calc: Total number of pupils included in the Progress 8 calculation.
# t_p8score: Total Progress 8 score for all pupils in the grouping.
# avg_p8score: Average Progress 8 score per pupil.
# p8score_ci_low: Lower bound of the Progress 8 score confidence interval.
# p8score_ci_upp: Upper bound of the Progress 8 score confidence interval.
