# %%
# import Python's library warning module
import warnings
warnings.filterwarnings("ignore")

# Import necessary libraries
import pandas as pd


# Load the CSV file from GitHub
date_file = 'Key-stage-4-performance---Academic-year-2022-23/2223_characteristics_summary_data_revised.csv'
data = pd.read_csv('2223_characteristics_summary_data_revised.csv')


# View Data
data
# Out:
#      time_period time_identifier geographic_level country_code country_name  \
# 0         202223   Academic year         National    E92000001      England
# 1         202223   Academic year         National    E92000001      England
# 2         202223   Academic year         National    E92000001      England
# 3         202223   Academic year         National    E92000001      England
# 4         202223   Academic year         National    E92000001      England
# ..           ...             ...              ...          ...          ...
# 259       201819   Academic year         National    E92000001      England
# 260       201819   Academic year         National    E92000001      England
# 261       201819   Academic year         National    E92000001      England
# 262       201819   Academic year         National    E92000001      England
# 263       201819   Academic year         National    E92000001      England
#
#      version establishment_type characteristics_group  \
# ...

# %%
# info() method for more deets
print("\nDataFrame Info:")
data.info()
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   time_period            264 non-null    int64
#  1   time_identifier        264 non-null    object
#  2   geographic_level       264 non-null    object
#  3   country_code           264 non-null    object
#  4   country_name           264 non-null    object
#  5   version                264 non-null    object
#  6   establishment_type     264 non-null    object
#  7   characteristics_group  264 non-null    object
#  8   characteristic         264 non-null    object
#  9   t_schools              264 non-null    int64
#  10  t_pupils               264 non-null    int64
#  11  t_att8                 264 non-null    float64
#  12  avg_att8               264 non-null    float64
#  13  t_entbasics            264 non-null    int64
# ...
